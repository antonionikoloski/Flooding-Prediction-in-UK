# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from mpl_toolkits.mplot3d import Axes3D

# 1. read data
file_path1 = "../flood_tool/example_data/typical_day.csv"
file_path2 = "../flood_tool/example_data/wet_day.csv"
file_path3 = "../flood_tool/resources/stations.csv"
def read_data(file_path):
    data = pd.read_csv(file_path)
    print
    return data

# %%
import pandas as pd
def processing_day(path):
    # 读取数据
    df=read_data(path)

    # 删除value列中的异常值
    df['value'] = pd.to_numeric(df['value'], errors='coerce')

    # 删除无用列
    df = df.drop(['dateTime', 'qualifier'], axis=1)
    df = df.dropna(subset=['value'])
    
    # 过滤单位不一致的数据
    df_filtered = df[((df['parameter'] == 'level') & (df['unitName'].isin(['mAOD', 'mASD']))) |
                 ((df['parameter'] == 'rainfall') & (df['unitName'].isin(['mm', 'm'])))]
    
    # 删除降雨量小于0的数据
    df_cleaned = df_filtered[(df_filtered['parameter'] != 'rainfall') | (df_filtered['value'] >= 0)]

    return df_cleaned

typical_day = processing_day(file_path1)
print(typical_day['unitName'].value_counts())
rainfall_data01 = typical_day[typical_day['parameter'] == 'rainfall']
rainfall_data01.describe()
# Out:
# unitName
# mASD    107725
# mm       85401
# mAOD     14970
# Name: count, dtype: int64
#               value
# count  85401.000000
# mean       0.001772
# std        0.061972
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        0.000000
# max       14.000000

# %%
wet_day = processing_day(file_path2)
print(wet_day['unitName'].value_counts())
wet_day.describe()
rainfall_data02 = wet_day[wet_day['parameter'] == 'rainfall']

rainfall_data02.describe()
# Out:
# unitName
# mASD    114127
# mm       81921
# mAOD      5487
# Name: count, dtype: int64
#               value
# count  81921.000000
# mean       0.262590
# std        2.233457
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        0.290000
# max      307.500000

# %%
def typical_wet_join(typical_day, wet_day,station):
    join_data = pd.concat([typical_day, wet_day], ignore_index=True)

    grouped = join_data.groupby(['stationReference', 'parameter', 'unitName'])['value'].agg(['mean', 'max', 'min'])
    grouped= grouped.reset_index()

    merged_data = pd.merge(station, grouped, 
                       on='stationReference', 
                       how='left')  
    return join_data, grouped,merged_data
station=read_data(file_path3)
null_columns = ["stationName","latitude","longitude"]
station = station.dropna(subset=null_columns)
station=station.drop(['maxOnRecord','minOnRecord','typicalRangeHigh','typicalRangeLow'], axis=1)

join_data,grouped,merge_data=typical_wet_join(typical_day, wet_day,station)
# join_data
# grouped
merge_data
# Out:
#      stationReference       stationName   latitude  longitude parameter  \
# 0              000008  Rainfall station  53.480556  -1.441674  rainfall
# 1              000028  Rainfall station  53.500289  -1.673575  rainfall
# 2            000075TP  Rainfall station  51.084022  -0.214597  rainfall
# 3            000076TP  Rainfall station  51.701508  -0.747539  rainfall
# 4            000180TP  Rainfall station  51.618838   0.173236  rainfall
# ...               ...               ...        ...        ...       ...
# 2019           E71839        Portsmouth  50.802280  -1.111170     level
# 2020           E71939       Bournemouth  50.714331  -1.874873     level
# 2021           E70739          Aberdeen  57.144060  -2.077360     level
# 2022           E74239         Tobermory  56.623110  -6.064220     level
# 2023           E73339         Llandudno  53.331670  -3.825220     level
#
#      unitName      mean    max    min
# 0          mm  0.386458  3.600  0.000
# 1          mm  0.442708  2.600  0.000
# 2          mm  0.015625  0.800  0.000
# 3          mm  0.109375  2.400  0.000
# 4          mm  0.027604  1.300  0.000
# ...       ...       ...    ...    ...
# 2019     mAOD  0.316703  2.024 -1.404
# 2020     mAOD -0.205497  0.923 -2.449
# 2021     mAOD  0.510167  1.886 -0.975
# 2022     mAOD  0.468979  1.716 -0.917
# 2023     mAOD  0.239375  2.853 -2.417
#
# [2024 rows x 9 columns]

# %%
merge_data.isnull().sum()
# Out:
# stationReference    0
# stationName         0
# latitude            0
# longitude           0
# parameter           0
# unitName            0
# mean                0
# max                 0
# min                 0
# dtype: int64

# %%
merge_data['parameter'].value_counts()
# Out:
# parameter
# level       1125
# rainfall     899
# Name: count, dtype: int64

# %%
level_data = merge_data[merge_data['parameter'] == 'level']
rainfall_data = merge_data[merge_data['parameter'] == 'rainfall']
level_data
rainfall_data
rainfall_data['mean'].min()
# Out:
# np.float64(0.0)

# %%
print(level_data['unitName'].value_counts())
print(rainfall_data['unitName'].value_counts())
# Out:
# unitName
# mASD    1077
# mAOD      48
# Name: count, dtype: int64
# unitName
# mm    899
# Name: count, dtype: int64

# %%
import folium
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors
from folium.plugins import HeatMap

# 假设 rainfall_data 是包含经纬度和 mean 值的数据框

m = folium.Map(location=[51, 0], zoom_start=13)

# Normalize 用于归一化 mean 值到 [0, 1] 的区间
norm = mcolors.Normalize(vmin=rainfall_data['mean'].min(), vmax=rainfall_data['mean'].max())

# 使用 matplotlib 中的渐变颜色映射
cmap = plt.cm.Reds  # 你也可以选择其他的 colormap，例如 Blues, YlGnBu 等

# 设置一个较明显的颜色映射范围（比如从红色到浅红色）
# 遍历 rainfall_data 中的每一行，根据 mean 值设置颜色
for _, row in rainfall_data.iterrows():
    # 根据 mean 值归一化得到一个值，然后映射到颜色
    color = mcolors.to_hex(cmap(norm(row['mean']))) 
    
    # 创建带颜色的 CircleMarker
    folium.CircleMarker(
        location=[row['latitude'], row['longitude']],
        radius=5,  # 根据需要调整圆的半径
        color=color,  # 圆的边框颜色
        fill=True,  
        fill_color=color,  # 填充颜色
        fill_opacity=0.7  # 填充透明度
    ).add_to(m)

# 显示地图
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f33099086e931e329e55b12a34d60f0d {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f33099086e931e329e55b12a34d60f0d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_f33099086e931e329e55b12a34d60f0d = L.map(
#                 &quot;map_f33099086e931e329e55b12a34d60f0d&quot;,
#                 {
#                     center: [51.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 13,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_be287606233833c9c72a60513ce2f13f = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_be287606233833c9c72a60513ce2f13f.addTo(map_f33099086e931e329e55b12a34d60f0d);
#
#
#             var circle_marker_e53e6aee0a47b6d0bee9f1d8ac4e025b = L.circleMarker(
#                 [53.480556, -1.441674],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#ffebe2&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#ffebe2&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_f33099086e931e329e55b12a34d60f0d);
#
#
#             var circle_marker_8a734769bb17c40811e23f7c740f31f2 = L.circleMarker(
#                 [53.500289, -1.673575],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#feeae0&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#feeae0&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_f33099086e931e329e55b12a34d60f0d);
#
#
#             var circle_marker_a2f28607785c8ce0cc4b0dcf665aaec1 = L.circleMarker(
#                 [51.084022, -0.214597],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#fff5f0&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#fff5f0&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_f33099086e931e329e55b12a34d60f0d);
#
#
#             var circle_marker_1d868a656196bdda1ecea28e326e89ee = L.circleMarker(
#                 [51.701508, -0.747539],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#fff2ec&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#fff2ec&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_f33099086e931e329e55b12a34d60f0d);
#
#
#             var circle_marker_fa91311a6152ae700ed5395647c13d8e = L.circleMarker(
#                 [51.618838, 0.173236],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#fff4ef&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#fff4ef&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_f33099086e931e329e55b12a34d60f0d);
#
#
#             var circle_marker_9d17b7f29a1e826197a816b6f3d1e56d = L.circleMarker(
#                 [51.730021, 0.040992],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#fff4ef&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#fff4ef&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_f33099086e931e329e55b12a34d60f0d);
#
#
#             var circle_marker_cbbd9ebab320ad4456c6663e1a7b7042 = L.circleMarker(
#                 [51.885257, -0.156869],
#                 {&quot;

# %%
# Out:
# /var/folders/9z/mm8bj8yn2yj6rk7vdlhpt07h0000gn/T/ipykernel_97051/1922941926.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rainfall_data['log_mean'] = np.log(rainfall_data['mean'] + 1e-5)
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_efa5d444ebf7a9d58ba7cf8e8c1f257a {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_efa5d444ebf7a9d58ba7cf8e8c1f257a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_efa5d444ebf7a9d58ba7cf8e8c1f257a = L.map(
#                 &quot;map_efa5d444ebf7a9d58ba7cf8e8c1f257a&quot;,
#                 {
#                     center: [51.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 13,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_2bf2d7163a15bf527116f647d3858590 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_2bf2d7163a15bf527116f647d3858590.addTo(map_efa5d444ebf7a9d58ba7cf8e8c1f257a);
#
#
#             var circle_marker_37058db83d833e747bea7822f4e4397f = L.circleMarker(
#                 [53.480556, -1.441674],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#be151a&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#be151a&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 8, &quot;stroke&quot;: true, &quot;weight&quot;: 0}
#             ).addTo(map_efa5d444ebf7a9d58ba7cf8e8c1f257a);
#
#
#             var circle_marker_729b2807f1d99b6503fd3f96cc716390 = L.circleMarker(
#                 [53.500289, -1.673575],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#bc141a&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#bc141a&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 8, &quot;stroke&quot;: true, &quot;weight&quot;: 0}
#             ).addTo(map_efa5d444ebf7a9d58ba7cf8e8c1f257a);
#
#
#             var circle_marker_55e40589a7c5ff1ea6119889f6de7842 = L.circleMarker(
#                 [51.084022, -0.214597],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#f6583e&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#f6583e&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 8, &quot;stroke&quot;: true, &quot;weight&quot;: 0}
#             ).addTo(map_efa5d444ebf7a9d58ba7cf8e8c1f257a);
#
#
#             var circle_marker_e620d8ed77e39ea6c3565a08a791059f = L.circleMarker(
#                 [51.701508, -0.747539],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#da2723&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#da2723&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 8, &quot;stroke&quot;: true, &quot;weight&quot;: 0}
#             ).addTo(map_efa5d444ebf7a9d58ba7cf8e8c1f257a);
#
#
#             var circle_marker_994b518ae210a62311d5612b6882af05 = L.circleMarker(
#                 [51.618838, 0.173236],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#f24734&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#f24734&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 8, &quot;stroke&quot;: true, &quot;weight&quot;: 0}
#             ).addTo(map_efa5d444ebf7a9d58ba7cf8e8c1f257a);
#
#
#             var circle_marker_a3ecf8773671d2a9bc03512fadfa8c91 = L.circleMarker(
#                 [51.730021, 0.040992],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#ec382b&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#ec382b&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 8, &quot;stroke&quot;: true, &quot;weight&quot;: 0}
#             ).addTo(map_efa5d444ebf7a9d58ba7cf8e8c1f257a);
#
#
#             var circle_marker_38797922da00006bc6792888d78315dd = L.circleMarker(
#                 [51.885257, -0.156869],
#                 {&quot;
