# %%
from os import path
import urllib
import json

import pandas as pd


API_URL = "http://environment.data.gov.uk/flood-monitoring/"
url = API_URL + "data/readings?latest" # I've changed the function here a little because I prefer to have unitName==mm 
data = urllib.request.urlopen(url)
data = json.load(data)
data
# Out:
# {'@context': 'http://environment.data.gov.uk/flood-monitoring/meta/context.jsonld',
#  'meta': {'publisher': 'Environment Agency',
#   'licence': 'http://www.nationalarchives.gov.uk/doc/open-government-licence/version/3/',
#   'documentation': 'http://environment.data.gov.uk/flood-monitoring/doc/reference',
#   'version': '0.9',
#   'comment': 'Status: Beta service',
#   'hasFormat': ['http://environment.data.gov.uk/flood-monitoring/data/readings.csv?latest',
#    'http://environment.data.gov.uk/flood-monitoring/data/readings.rdf?latest',
#    'http://environment.data.gov.uk/flood-monitoring/data/readings.ttl?latest',
#    'http://environment.data.gov.uk/flood-monitoring/data/readings.html?latest']},
#  'items': [{'@id': 'http://environment.data.gov.uk/flood-monitoring/data/readings/7056-level-groundwater-i-15_min-mBDAT/2024-10-24T14-30-00Z',
#    'dateTime': '2024-10-24T14:30:00Z',
#    'measure': 'http://environment.data.gov.uk/flood-monitoring/id/measures/7056-level-groundwater-i-15_min-mBDAT',
#    'value': 17.816},
#   {'@id': 'http://environment.data.gov.uk/flood-monitoring/data/readings/50105-rainfall-tipping_bucket_raingauge-t-15_min-mm/2024-10-25T08-00-00Z',
#    'dateTime': '2024-10-25T08:00:00Z',
#    'measure': 'http://environment.data.gov.uk/flood-monitoring/id/measures/50105-rainfall-tipping_bucket_raingauge-t-15_min-mm',
#    'value': 0.0},
#   {'@id': 'http://environment.data.gov.uk/flood-monitoring/data/readings/47113-rainfall-tipping_bucket_raingauge-t-15_min-mm/2024-10-28T12-00-00Z',
#    'dateTime': '2024-10-28T12:00:00Z',
#    'measure': 'http://environment.data.gov.uk/flood-monitoring/id/measures/47113-rainfall-tipping_bucket_raingauge-t-15_min-mm',
#    'value': 0.3},
#   {'@id': 'http://environment.data.gov.uk/flood-monitoring/data/readings/3207TH-level-stage-i-15_min-mASD/2024-10-29T16-42-04Z',
#    'dateTime': '2024-10-29T16:42:04Z',
#    'measure': 'http://environment.data.gov.uk/flood-monitoring/id/measures/3207TH-level-stage-i-15_min-mASD',
#    'value': 0.0},
#   {'@id': 'http://environment.data.gov.uk/flood-monitoring/data/readings/2436TH-level-stage-i-15_min-mAOD/2024-10-30T13-15-00Z',
#    'dateTime': '2024-10-30T13:15:00Z',
#    'measure': 'http://environment.data.gov.uk/flood-monitoring/id/measures/2436TH-level-stage-i-15_min-mAOD',
#    'value': 46.807},
#   {'@id': 'http://environment.data.gov.uk/flood-monitoring/data/readings/E2902-level-stage-i-15_min-mASD/2024-11-06T07-46-56Z',
#    'dateTime': '2024-11-06T07:46:56Z',
#    'measure': 'http://environment.data.gov.uk/flood-monitoring/id/measures/E2902-level-stage-i-15_min-mASD',
#    'value': 0.133},
#   {'@id': 'http://environment.data.gov.uk/flood-monitoring/data/readings/SU48_64-level-groundwater-i-1_h-mAOD/2024-11-07T07-00-00Z',
#    'dateTime': '2024-11-07T07:00:00Z',
#    'measure': 'http://environment.data.gov.uk/flood-monitoring/id/measures/SU48_64-level-groundwater-i-1_h-mAOD',
#    'value': 104.896},
#   {'@id': 'http://environment.data.gov.uk/flood-monitoring/data/readings/49110-level-1-i-15_min-m/2024-11-11T12-45-00Z',
#    'dateTime': '2024-11-11T12:45:00Z',
#    'measure': 'http://environment.data.gov.uk/flood-monitoring/id/measures/49110-level-1-i-15_min-m',
#    'value': 0.31},
#   {'@id': 'http://environment.data.gov.uk/flood-monitoring/data/readings/SU47_140-level-groundwater-i-1_h-mAOD/2024-11-12T05-00-00Z',
#    'dateTime': '2024-11-12T05:00:00Z',
#    'measure': 'http://environment.data.gov.uk/flood-monitoring/id/measures/SU47_140-level-groundwater-i-1_h-mAOD',
#    'value': 101.99},
#   {'@id': 'http://environment.data.gov.uk/flood-monitoring/data/readings/E24255-level-stage-i-15_min-mASD/2024-11-13T04-30-00Z',
#    'dateTime': '2024-11-13T04:30:00Z',
#    'measure': 'http://environment.data.gov.uk/flood-monitoring/id/measures/E24255-level-stage-i-15_min-mASD',
#    'value': 0.319},
#   {'@id': 'http://environment.data.gov.uk/flood-monitoring/data/readings/2218-level-stage-i-15_min-mASD/2024-11-14T10-45-00Z',
#    'dateTime': '2024-11-14T10:45:00Z',
#    'measure': 'http://environment.data.gov.uk/flood-monitoring/id/measures/2218-level-stage-i-15_min-mASD',
#    'value': 0.174},
#   {'@id': 'http://environment.data.gov.uk/flood-monitoring/data/readings/SU57_156-level-groundwater-i-1_h-mAOD/2024-11-15T10-00-00Z',
#    'dateTime': '2024-11-15T10:00:00Z',
#    'measure': 'http://environment.data.gov.uk/flood-monitoring/id/measures/SU57_156-level-groundwater-i-1_h-mAOD',
#    'value': 92.504},
#   {'@id': 'http://environment.data.gov.uk/flood-monitoring/data/readings/SU57_155-level-groundwater-i-1_h-mAOD/2024-11-15T10-00-00Z',
#    'dateTime': '2024-11-15T10:00:00Z',
#    'measure': 'http://environment.data.gov.uk/flood-monitoring/id/measures/SU57_155-level-groundwater-i-1_h-mAOD',
#    'value': 90.273},
#   {'@id': 'http://environment.data.gov.uk/flood-monitoring/data/readings/5116-level-downstage-i-15_min-m/2024-11-15T17-15-00Z',
#    'dateTime': '2024-11-15T17:15:00Z',
#    'measure': 'http://environment.data.gov.uk/flood-monitoring/id/measures/5116-level-downstage-i-15_min-m',
#    'value': 0.14},
#   {'@id': 'http://environment.data.gov.uk/flood-monitoring/data/readings/5000-level-groundwater-i-1_h-mBDAT/2024-11-16T14-30-00Z',
#    'dateTime': '2024-11-16T14:30:00Z',
#    'measure': 'http://environment.data.gov.uk/flood-monitoring/id/measures/5000-level-groundwater-i-1_h-mBDAT',
#    'value': 4.465},
#   {'@id': 'http://environment.data.gov.uk/flood-monitoring/data/readings/036225-rainfall-tipping_bucket_raingauge-t-15_min-mm/2024-11-17T15-45-00Z',
#    'dateTime': '2024-11-17T15:45:00Z',
#    'measure': 'http://environment.data.gov.uk/flood-monitoring/id/measures/036225-rainfall-tipping_bucket_raingauge-t-15_min-mm',
#    'value': 0.0},
#   {'@id': 'http://environment.data.gov.uk/flood-monitoring/data/readings/E22563-level-stage-i-15_min-m/2024-11-17T19-15-00Z',
#    'dateTime': '2024-11-17T19:15:00Z',
#    'measure': 'http://environment.data.gov.uk/flood-monitoring/id/measures/E22563-level-stage-i-15_min-m',
#    'value': 0.22},
#   {'@id': 'http://environment.data.gov.uk/flood-monitoring/data/readings/E22564-flow-stage-i-15_min-m3_s/2024-11-17T19-15-00Z',
#    'dateTime': '2024-11-17T19:15:00Z',
#    'measure': 'http://environment.data.gov.uk/flood-monitoring/id/measures/E22564-flow-stage-i-15_min-m3_s',
#    'value': 0.065},
#   {'@id': 'http://environment.data.gov.uk/flood-monitoring/data/readings/5116-level-stage-i-15_min-mASD/2024-11-17T20-30-00Z',
#    'dateTime': '2024-11-17T20:30:00Z',
#    'measure': 'http://environment.data.gov.uk/flood-monitoring/id/measures/5116-level-stage-i-15_min-mASD',
#    'value': 0.153},
#   {'@id': 'http://environment.data.gov.uk/flood-monitoring/data/readings/5116-level-downstage-i-15_min-mASD/2024-11-17T20-30-00Z',
#    'dateTime': '2024-11-17T20:30:00Z',
#    'measure': 'http://environment.data.gov.uk/flood-monitoring/id/measures/5116-level-downstage-i-15_min-mASD',
#    'value': 0.143},
#   {'@id': 'http://environment.data.gov.uk/flood-monitoring/data/readings/43198-level-groundwater-i-15_min-mAOD/2024-11-17T23-00-00Z',
#    'dateTime': '2024-11-17T23:00:00Z',
#    'measure': 'http://environment.data.gov.uk/flood-monitoring/id/measures/43198-level-groundwater-i-15_min-mAOD',
#    'value': 50.7},
#   {'@id': 'http://environment.data.gov.uk/flood-monitoring/data/readings/SP10_53-level-groundwater-i-1_h-mAOD/2024-11-18T10-00-00Z',
#    'dateTime': '2024-11-18T10:00:00Z',
#    'measure': 'http://environment.data.gov.uk/flood-monitoring/id/measures/SP10_53-level-groundwater-i-1_h-mAOD',
#    'value': 93.592},
#   {'@id': 'http://environment.data.gov.uk/flood-monitoring/data/readings/53126-level-stage-i-15_min-mASD/2024-11-19T03-45-00Z',
#    'dateTime': '2024-11-19T03:45:00Z',
#    'measure': 'http://environment.data.gov.uk/flood-monitoring/id/measures/53126-level-stage-i-15_min-mASD',
#    'value': 0.775},
#   {'@id': 'http://environment.data.gov.uk/flood-monitoring/data/readings/E23028-level-stage-i-15_min-m/2024-11-19T04-30-00Z',
#    'dateTime': '2024-11-19T04:30:00Z',
#    'measure': 'http://environment.data.gov.uk/flood-monitoring/id/measures/E23028-level-stage-i-15_min-m',
#    'value': 0.233},
#   {'@id': 'http://environment.data.gov.uk/flood-monitoring/data/readings/E22844-flow-stage-i-15_min-m3_s/2024-11-19T05-15-00Z',
#    'dateTime': '2024-11-19T05:15:00Z',
#    'measure': 'http://environment.data.gov.uk/flood-monitoring/id/measures/E22844-flow-stage-i-15_min-m3_s',
#    'value': 0.269},
#   {'@id': 'http://environment.data.gov.uk/flood-monitoring/data/readings/E22843-level-stage-i-15_min-m/2024-11-19T05-15-00Z',
#    'dateTime': '2024-11-19T05:15:00Z',
#    'measure': 'http://environment.data.gov.uk/flood-monitoring/id/measures/E22843-level-stage-i-15_min-m',
#    'value': 0.259},
#   {'@id': 'http://environment.data.gov.uk/flood-monitoring/data/readings/5263TH-level-stage-i-15_min-mASD/2024-11-19T06-30-00Z',
#    'dateTime': '2024-11-19T06:30:00Z',
#    'measure': 'http://environment.data.gov.uk/flood-monitoring/id/measures/5263TH-level-stage-i-15_min-mASD',
#    'value': 30.641},
#   {'@id': 'http://environment.data.gov.uk/flood-monitoring/data/readings/45175-level-groundwater-i-15_min-m/2024-11-19T07-00-00Z',
#    'dateTime': '2024-11-19T07:00:00Z',
#    'measure': 'http://environment.data.gov.uk/flood-monitoring/id/measures/45175-level-groundwater-i-15_min-m',
#    'value': 3.042},
#   {'@id': 'http://environment.data.gov.uk/flood-monitoring/data/readings/46124-level-stage-i-15_min-m/2024-11-19T07-15-00Z',
#    'dateTime': '2024-11-19T07:15:00Z',
#    'measure': 'http://environment.data.gov.uk/flood-monitoring/id/measures/46124-level-stage-i-15_min-m',
#    'value': 0.998},
#   {'@id': 'http://environment.data.gov.uk/flood-monitoring/data/readings/2879_w1TH-level-downstage-i-15_min-mASD/2024-11-19T07-30-00Z',
#    'dateTime': '2024-11-19T07:30:00Z',
#    'measure': 'http://environment.data.gov.uk/flood-monitoring/id/measures/2879_w1TH-level-downstage-i-15_min-mASD',
#    'value': -0.057},
#   {'@id': 'http://environment.data.gov.uk/flood-monitoring/data/readings/2879_w1TH-level-stage-i-15_min-mASD/2024-11-19T07-30-00Z',
#    'dateTime': '2024-11-19T07:30:00Z',
#    'measure': 'http://environment.data.gov.uk/flood-monitoring/id/measures/2879_w1TH-level-stage-i-15_min-mASD',
#    'value': 0.138},
#   {'@id': 'http://environment.data.gov.uk/flood-monitoring/data/readings/2989TH-level-stage-i-15_min-mASD/2024-11-19T07-45-00Z',
#    'dateTime': '2024-11-19T07:45:00Z',
#    'measure': 'http://environment.data.gov.uk/flood-monitoring/id/measures/2989TH-level-stage-i-15_min-mASD',
#    'value': 0.497},
#   {'@id': 'http://environment.data.gov.uk/flood-monitoring/data/readings/2989TH-flow-water-i-15_min-m3_s/2024-11-19T07-45-00Z',
#    'dateTime': '2024-11-19T07:45:00Z',
#    'measure': 'http://environment.data.gov.uk/flood-monitoring/id/measures/2989TH-flow-water-i-15_min-m3_s',
#    'value': 1.189},
#   {'@id': 'http://environment.data.gov.uk/flood-monitoring/data/readings/E80903-level-stage-i-15_min-m/2024-11-19T08-00-00Z',
#    'dateTime': '2024-11-19T08:00:00Z',
#    'measure': 'http://environment.data.gov.uk/flood-monitoring/id/measures/E80903-level-stage-i-15_min-m',
#    'value': 0.091},
#   {'@id': 'http://environment.data.gov.uk/flood-monitoring/data/readings/47159-rainfall-tipping_bucket_raingauge-t-15_min-mm/2024-11-19T09-00-00Z',
#    'dateTime': '2024-11-19T09:00:00Z',
#    'measure': 'http://environment.data.gov.uk/flood-monitoring/id/measures/47159-rainfall-tipping_bucket_raingauge-t-15_min-mm',
#    'value': 0.1},
#   {'@id': 'http://environment.data.gov.uk/flood-monitoring/data/readings/SU27_68-level-groundwater-i-1_h-mAOD/2024-11-19T10-00-00Z',
#    'dateTime': '2024-11-19T10:00:00Z',
#    'measure': 'http://environment.data.gov.uk/flood-monitoring/id/measures/SU27_68-level-groundwater-i-1_h-mAOD',
#    'value': 139.71},
#   {'@id': 'http://environment.data.gov.uk/flood-monitoring/data/readings/9408SE-level-groundwater-i-1_h-mAOD/2024-11-19T11-00-00Z',
#    'dateTime': '2024-11-19T11:00:00Z',
#    'measure': 'http://environment.data.gov.uk/flood-monitoring/id/measures/9408SE-level-groundwater-i-1_h-mAOD',
#    'value': 27.258},
#   {'@id': 'http://environment.data.gov.uk/flood-monitoring/data/readings/E2534-velocity-4-i-15_min-m_s/2024-11-19T13-00-00Z',
#    'dateTime': '2024-11-19T13:00:00Z',
#    'measure': 'http://environment.data.gov.uk/flood-monitoring/id/measures/E2534-velocity-4-i-15_min-m_s',
#    'value': 0.463},
#   {'@id': 'http://environment.data.gov.uk/flood-monitoring/data/readings/E2534-velocity-3-i-15_min-m_s/2024-11-19T13-00-00Z',
#    'dateTime': '2024-11-19T13:00:00Z',
#    'measure': 'http://environment.data.gov.uk/flood-monitoring/id/measures/E2534-velocity-3-i-15_min-m_s',
#    'value': 0.364},
#   {'@id': 'http://environment.data.gov.uk/flood-monitoring/data/readings/2849TH-level-stage-i-15_min-mASD/2024-11-19T13-45-00Z',
#    'dateTime': '2024-11-19T13:45:00Z',
#    'measure': 'http://environment.data.gov.uk/flood-monitoring/id/measures/2849TH-level-stage-i-15_min-mASD',
#    'value': 0.183},
#   {'@id': 'http://environment.data.gov.uk/flood-monitoring/data/readings/5912-level-groundwater-i-15_min-mBDAT/2024-11-19T14-30-00Z',
#    'dateTime': '2024-11-19T14:30:00Z',
#    'measure': 'http://environment.data.gov.uk/flood-monitoring/id/measures/5912-level-groundwater-i-15_min-mBDAT',
#    'value': 6.074},
#   {'@id': 'http://environment.data.gov.uk/flood-monitoring/data/readings/E22400-rainfall-tipping_bucket_raingauge-t-15_min-mm/2024-11-19T20-30-00Z',
#    'dateTime': '2024-11-19T20:30:00Z',
#    'measure': 'http://environment.data.gov.uk/flood-monitoring/id/measures/E22400-rainfall-tipping_bucket_raingauge-t-15_min-mm',
#    'value': 0.0},
#   {'@id': 'http://environment.data.gov.uk/flood-monitoring/data/readings/5321TH-level-stage-i-15_min-mAOD/2024-11-19T21-00-00Z',
#    'dateTime': '2024-11-19T21:00:00Z',
#    'measure': 'http://environment.data.gov.uk/flood-monitoring/id/measures/5321TH-level-stage-i-15_min-mAOD',
#    'value': 0.145},
#   {'@id': 'http://environment.data.gov.uk/flood-monitoring/data/readings/9403SE-level-groundwater-i-1_h-mAOD/2024-11-19T17-00-00Z',
#    'dateTime': '2024-11-19T17:00:00Z',
#    'measure': 'http://environment.data.gov.uk/flood-monitoring/id/measures/9403SE-level-groundwater-i-1_h-mAOD',
#    'value': 76.553},
#   {'@id': 'http://environment.data.gov.uk/flood-monitoring/data/readings/E22832-level-stage-i-15_min-m/2024-11-19T19-15-00Z',
#    'dateTime': '2024-11-19T19:15:00Z',
#    'measure': 'http://environment.data.gov.uk/flood-monitoring/id/measures/E22832-level-stage-i-15_min-m',
#    'value': 0.316},
#   {'@id': 'http://environment.data.gov.uk/flood-monitoring/data/readings/E24874-rainfall-tipping_bucket_raingauge-t-15_min-mm/2024-11-19T20-30-00Z',
#    'dateTime': '2024-11-19T20:30:00Z',
#    'measure': 'http://environment.data.gov.uk/flood-monitoring/id/measures/E24874-rainfall-tipping_bucket_raingauge-t-15_min-mm',
#    'value': 0.0},
#   {'@id': 'http://environment.data.gov.uk/flood-monitoring/data/readings/E22129-level-tidal_level-i-15_min-mAOD/2024-11-19T16-15-00Z',
#    'dateTime': '2024-11-19T16:15:00Z',
#    'measure': 'http://environment.data.gov.uk/flood-monitoring/id/measures/E22129-level-tidal_level-i-15_min-mAOD',
#    'value': 0.688},
#   {'@id': 'http://environment.data.gov.uk/flood-monitoring/data/readings/E22834-flow-stage-i-15_min-m3_s/2024-11-19T19-15-00Z',
#    'dateTime': '2024-11-19T19:15:00Z',
#    'measure': 'http://environment.data.gov.uk/flood-monitoring/id/measures/E22834-flow-stage-i-15_min-m3_s',
#    'value': 0.793},
#   {'@id': 'http://environment.data.gov.uk/flood-monitoring/data/readings/
level-stage-i-15_min-m/2024-11-21T16-00-00Z',
#    'dateTime': '2024-11-21T16:00:00Z',
#    'measure': 'http://environment.data.gov.uk/flood-monitoring/id/measures/43114-level-stage-i-15_min-m',
#    'value': 0.344},
#   {'@id': 'http://environment.data.gov.uk/flood-monitoring/data/readings/531175-rainfall-tipping_bucket_raingauge-t-15_min-mm/2024-11-21T16-00-00Z',
#    'dateTime': '2024-11-21T16:00:00Z',
#    'measure': 'http://environment.data.gov.uk/flood-monitoring/id/measures/531175-rainfall-tipping_bucket_raingauge-t-15_min-mm',
#    'value': 0.0},
#   {'@id': 'http://environment.data.gov.uk/flood-monitoring/data/readings/47168-rainfall-tipping_bucket_raingauge-t-15_min-mm/2024-11-21T16-00-00Z',
#    'dateTime': '2024-11-21T16:00:00Z',
#    'measure': 'http://environment.data.gov.uk/flood-monitoring/id/measures/47168-rainfall-tipping_bucket_raingauge-t-15_min-mm',
#    'value': 0.0},
#   {'@id': 'http://environment.data.gov.uk/flood-monitoring/data/readings/47139-level-stage-i-15_min-m/2024-11-21T16-00-00Z',
#    'dateTime': '2024-11-21T16:00:00Z',
#    'measure': 'http://environment.data.gov.uk/flood-monitoring/id/measures/47139-level-stage-i-15_min-m',
#    'value': 0.618},
#   {'@id': 'http://environment.data.gov.uk/flood-monitoring/data/readings/48140-level-stage-i-15_min-m/2024-11-21T16-00-00Z',
#    'dateTime': '2024-11-21T16:00:00Z',
#    'measure': 'http://environment.data.gov.uk/flood-monitoring/id/measures/48140-level-stage-i-15_min-m',
#    'value': 0.617},
#   {'@id': 'http://environment.data.gov.uk/flood-monitoring/data/readings/46126-level-stage-i-15_min-m/2024-11-21T16-00-00Z',
#    'dateTime': '2024-11-21T16:00:00Z',
#    'measure': 'http://environment.data.gov.uk/flood-monitoring/id/measures/46126-level-stage-i-15_min-m',
#    'value': 0.398},
#   {'@id': 'http://environment.data.gov.uk/flood-monitoring/data/readings/43123-level-stage-i-15_min-m/2024-11-21T16-00-00Z',
#    'dateTime': '2024-11-21T16:00:00Z',
#    'measure': 'http://environment.data.gov.uk/flood-monitoring/id/measures/43123-level-stage-i-15_min-m',
#    'value': 1.116},
#   {'@id': 'http://environment.data.gov.uk/flood-monitoring/data/readings/49121-level-stage-i-15_min-m/2024-11-21T16-00-00Z',
#    'dateTime': '2024-11-21T16:00:00Z',
#    'measure': 'http://environment.data.gov.uk/flood-monitoring/id/measures/49121-level-stage-i-15_min-m',
#    'value': 0.396},
#   {'@id': 'http://environment.data.gov.uk/flood-monitoring/data/readings/46123-level-2-i-15_min-m/2024-11-21T16-00-00Z',
#    'dateTime': '2024-11-21T16:00:00Z',
#    'measure': 'http://environment.data.gov.uk/flood-monitoring/id/measures/46123-level-2-i-15_min-m',
#    'value': 0.578},
#   {'@id': 'http://environment.data.gov.uk/flood-monitoring/data/readings/50135-level-stage-i-15_min-m/2024-11-21T16-00-00Z',
#    'dateTime': '2024-11-21T16:00:00Z',
#    'measure': 'http://environment.data.gov.uk/flood-monitoring/id/measures/50135-level-stage-i-15_min-m',
#    'value': 0.349},
#   {'@id': 'http://environment.data.gov.uk/flood-monitoring/data/readings/48128-level-stage-i-15_min-m/2024-11-21T16-00-00Z',
#    'dateTime': '2024-11-21T16:00:00Z',
#    'measure': 'http://environment.data.gov.uk/flood-monitoring/id/measures/48128-level-stage-i-15_min-m',
#    'value': 0.382},
#   {'@id': 'http://environment.data.gov.uk/flood-monitoring/data/readings/47115-level-stage-i-15_min-m/2024-11-21T16-00-00Z',
#    'dateTime': '2024-11-21T16:00:00Z',
#    'measure': 'http://environment.data.gov.uk/flood-monitoring/id/measures/47115-level-stage-i-15_min-m',
#    'value': 1.035},
#   {'@id': 'http://environment.data.gov.uk/flood-monitoring/data/readings/43115-level-stage-i-15_min-m/2024-11-21T16-00-00Z',
#    'dateTime': '2024-11-21T16:00:00Z',
#    'measure': 'http://environment.data.gov.uk/flood-monitoring/id/measures/43115-level-stage-i-15_min-m',
#    'value': 0.231},
#   {'@id': 'http://environment.data.gov.uk/flood-monitoring/data/readings/48182-rainfall-tipping_bucket_raingauge-t-15_min-mm/2024-11-21T16-00-00Z',
#    'dateTime': '2024-11-21T16:00:00Z',
#    'measure': 'http://environment.data.gov.uk/flood-monitoring/id/measures/48182-rainfall-tipping_bucket_raingauge-t-15_min-mm',
#    'value': 0.0},
#   {'@id': 'http://environment.data.gov.uk/flood-monitoring/data/readings/43203-rainfall-tipping_bucket_raingauge-t-15_min-mm/2024-11-21T16-00-00Z',
#    'dateTime': '2024-11-21T16:00:00Z',
#    'measure': 'http://environment.data.gov.uk/flood-monitoring/id/measures/43203-rainfall-tipping_bucket_raingauge-t-15_min-mm',
#    'value': 0.0},
#   {'@id': 'http://environment.data.gov.uk/flood-monitoring/data/readings/48127-level-stage-i-15_min-m/2024-11-21T16-00-00Z',
#    'dateTime': '2024-11-21T16:00:00Z',
#    'measure': 'http://environment.data.gov.uk/flood-monitoring/id/measures/48127-level-stage-i-15_min-m',
#    'value': 0.658},
#   {'@id': 'http://environment.data.gov.uk/flood-monitoring/data/readings/48106-rainfall-tipping_bucket_raingauge-t-15_min-mm/2024-11-21T16-00-00Z',
#    'dateTime': '2024-11-21T16:00:00Z',
#    'measure': 'http://environment.data.gov.uk/flood-monitoring/id/measures/48106-rainfall-tipping_bucket_raingauge-t-15_min-mm',
#    'value': 0.0},
#   ...]}

# %% [markdown]
# # Observe Data and Encapsulate Functions
#
# Define the functions `get_latest_rainfall_readings`, `get_latest_tide_readings`, and `get_latest_river_readings` as follows:
#
# - **Data Observation**:
#   - The raw data, after being retrieved, contains the key information within the `items` field. Extract this as the initial dataset.
#   - From the `@id` field in `items`, all relevant metadata (such as `stationReference`, `qualifier`, and `unitName`) can be extracted. To achieve this, define the helper functions `split_rainfall_api_id` and `split_level_api_id` that use string splitting to isolate the desired information.
#
# - **Data Extraction**:
#   - Extract additional relevant fields, such as `dateTime` and `value`, from the `items` field.
#   - Construct and return a DataFrame with the cleaned and structured data.
#
# ---
#
# # Implementation Steps
#
# ### 1. Write Functions for Data Retrieval:
# Develop functions that fetch the latest `rainfall`, `tide`, and `river` data, storing the results in individual DataFrames (`live_data`).
#
# ### 2. Process Each Dataset:
# Utilize the flood tool's functions to handle `rainfall`, `tide`, and `river` data separately. This modular approach simplifies visualization tasks later.
#
# ### 3. Visualize Risk Areas:
# Leverage flood tool utilities to identify and visualize potential areas at risk. Generate plots showing the distribution of high-risk regions based on live data.
#
# By modularizing each step, you ensure a clean workflow for data retrieval, processing, and visualization.

# %% [markdown]
# # 1. get live data

# %% [markdown]
# ## 1.1 get live rainfall data

# %%
def split_rainfall_api_id(input):
    """
    Split rainfall station API id into component parts
    """
    try:
        # Split Path
        parts = input.split('/')
        # Find the section that contains the key information
        target_part = parts[-2] 
        # Further split into target fields
        station, qualifier, unit = target_part.split('-rainfall-')[0], \
                                          target_part.split('-rainfall-')[1].split('-t-15_min-')[0], \
                                          target_part.split('-t-15_min-')[1]
        return station, qualifier, unit
    except (IndexError, ValueError):
        # Returns a null value to handle an exception
        return "", "", ""
    
def extract_station_reference(x):
    """Extract stationReference"""
    return x[0]

def extract_qualifier(x):
    """Extract qualifier and format"""
    return x[1].replace('_', ' ').title()

def extract_unit_name(x):
    """Extract unitName"""
    return x[2]




def get_latest_rainfall_readings(url_rainfall):
    """
    Fetches the latest rainfall readings from a live API, processes the data, 
    and returns it as a structured DataFrame.

    Parameters:
    url_rainfall (str): URL of the live API providing rainfall data.

    Returns:
    pandas.DataFrame: A DataFrame of rainfall data filtered by unit (mm), indexed by 
                      stationReference and dateTime, with relevant metadata included.
    """
    data = urllib.request.urlopen(url_rainfall)
    data = json.load(data)

    df_item = pd.DataFrame(data["items"])

    id_data = df_item["@id"].apply(split_rainfall_api_id)
    df_item["stationReference"] = id_data.apply(extract_station_reference)
    df_item["qualifier"] = id_data.apply(extract_qualifier)
    df_item["unitName"] = id_data.apply(extract_unit_name)


    df_item.drop(["@id", "measure"], axis=1, inplace=True)

    df_item["dateTime"] = df_item["dateTime"].apply(pd.to_datetime)

    df_item.set_index(["stationReference", "dateTime"], inplace=True)

    df_item["parameter"] = "rainfail"

    df_item["value"] = pd.to_numeric(df_item["value"], errors="coerce")
    df_item = df_item[df_item['unitName'] == 'mm']

    return df_item.sort_index()

url_rainfall= "http://environment.data.gov.uk/flood-monitoring/data/readings?latest&unitName=mm"
live_rainfall = get_latest_rainfall_readings(url_rainfall)#.shape#parameter.value_counts()
live_rainfall.reset_index(inplace=True)
live_rainfall
# Out:
#      stationReference                  dateTime  value  \
# 0              000008 2024-11-21 23:00:00+00:00    0.0
# 1              000028 2024-11-21 23:00:00+00:00    0.0
# 2            000075TP 2024-11-21 23:00:00+00:00    0.0
# 3            000076TP 2024-11-21 23:00:00+00:00    0.0
# 4            000180TP 2024-11-21 23:00:00+00:00    0.0
# ..                ...                       ...    ...
# 888          Egerton1 2024-11-21 23:00:00+00:00    0.0
# 889          NelsonGC 2024-11-21 23:00:00+00:00    0.0
# 890     Not_Specified 2024-11-21 16:00:00+00:00    0.0
# 891     Not_Specified 2024-11-21 20:45:00+00:00    0.0
# 892  VCHURCH-T_TG_341 2024-11-21 23:00:00+00:00    0.0
#
#                     qualifier unitName parameter
# 0    Tipping Bucket Raingauge       mm  rainfail
# 1    Tipping Bucket Raingauge       mm  rainfail
# 2    Tipping Bucket Raingauge       mm  rainfail
# 3    Tipping Bucket Raingauge       mm  rainfail
# 4    Tipping Bucket Raingauge       mm  rainfail
# ..                        ...      ...       ...
# 888  Tipping Bucket Raingauge       mm  rainfail
# 889  Tipping Bucket Raingauge       mm  rainfail
# 890                         1       mm  rainfail
# 891                         2       mm  rainfail
# 892  Tipping Bucket Raingauge       mm  rainfail
#
# [893 rows x 6 columns]

# %% [markdown]
# ## 1.2 get live tide data

# %%
def split_level_api_id(input):
    """
    Split level station API id into component parts
    """
    try:
        # Split Path
        parts = input.split('/')
        # Find the section that contains the key information
        target_part = parts[-2] 
        # Further split into target fields
        station, qualifier, unit = target_part.split('-level-')[0], \
                                          target_part.split('-level-')[1].split('-i-15_min-')[0], \
                                          target_part.split('-i-15_min-')[1]
        return station, qualifier, unit
    except (IndexError, ValueError):
        # Returns a null value to handle an exception
        return "", "", ""
    
def extract_station_reference(x):
    """extract stationReference"""
    return x[0]

def extract_qualifier(x):
    """extract qualifier and format"""
    return x[1].replace('_', ' ').title()

def extract_unit_name(x):
    """extract unitName"""
    return x[2]


def get_latest_tide_readings(url_tide):
    """
    Fetches the latest tide readings from a live API, processes the data, 
    and returns it as a structured DataFrame.

    Parameters:
    url_tide (str): URL of the live API providing tide data.

    Returns:
    pandas.DataFrame: A DataFrame of tide data filtered by unit (mAOD), indexed by 
                      stationReference and dateTime, with relevant data included.
    """
    data = urllib.request.urlopen(url_tide)
    data = json.load(data)

    df_item = pd.DataFrame(data["items"])

    id_data = df_item["@id"].apply(split_level_api_id)
    df_item["stationReference"] = id_data.apply(extract_station_reference)
    df_item["qualifier"] = id_data.apply(extract_qualifier)
    df_item["unitName"] = id_data.apply(extract_unit_name)


    df_item.drop(["@id", "measure"], axis=1, inplace=True)

    df_item["dateTime"] = df_item["dateTime"].apply(pd.to_datetime)

    df_item.set_index(["stationReference", "dateTime"], inplace=True)

    # df_item["parameter"] = "rainfail"

    df_item["value"] = pd.to_numeric(df_item["value"], errors="coerce")
    # df_item.dropna(['unitName'], inplace=True)
    df_item = df_item[df_item['unitName'] == 'mAOD']

    return df_item.sort_index()

url_tide= "http://environment.data.gov.uk/flood-monitoring/data/readings?latest"

live_tide = get_latest_tide_readings(url_tide)#.shape#parameter.value_counts()
live_tide.reset_index(inplace=True)
live_tide
# Out:
#     stationReference                  dateTime   value    qualifier unitName
# 0               0001 2024-11-21 23:00:00+00:00  -1.908  Tidal Level     mAOD
# 1               0003 2024-11-21 23:00:00+00:00  -1.950  Tidal Level     mAOD
# 2               0004 2024-11-21 23:00:00+00:00  -1.144  Tidal Level     mAOD
# 3               0006 2024-11-21 23:00:00+00:00  -1.453  Tidal Level     mAOD
# 4               0007 2024-11-21 23:00:00+00:00  -1.858  Tidal Level     mAOD
# ..               ...                       ...     ...          ...      ...
# 755       TA06MF00CC 2024-11-21 18:00:00+00:00  26.451  Groundwater     mAOD
# 756       TA06NPSLCC 2024-11-21 18:00:00+00:00  19.775  Groundwater     mAOD
# 757       TA07RSNLCC 2024-11-21 18:00:00+00:00  28.170  Groundwater     mAOD
# 758       TA08IOW1CO 2024-11-21 18:00:00+00:00  29.973  Groundwater     mAOD
# 759             TORQ 2024-11-21 23:00:00+00:00   1.051  Tidal Level     mAOD
#
# [760 rows x 5 columns]

# %% [markdown]
# ## 1.3 get live river data

# %%
def split_level_api_id(input):
    """
    Split rainfall station API id into component parts
    without using a regular expression.
    """
    try:
        # Split Path
        parts = input.split('/')
        # Find the section that contains the key information
        target_part = parts[-2] 
        # Further split into target fields
        station, qualifier, unit = target_part.split('-level-')[0], \
                                          target_part.split('-level-')[1].split('-i-15_min-')[0], \
                                          target_part.split('-i-15_min-')[1]
        return station, qualifier, unit
    except (IndexError, ValueError):
        # Returns a null value to handle an exception
        return "", "", ""
    
def extract_station_reference(x):
    """extract stationReference"""
    return x[0]

def extract_qualifier(x):
    """extract qualifier and format"""
    return x[1].replace('_', ' ').title()

def extract_unit_name(x):
    """extract unitName"""
    return x[2]



def get_latest_river_readings(url_river):
    """
    Fetches the latest river readings from a live API, processes the data, 
    and returns it as a structured DataFrame.

    Parameters:
    url_river (str): URL of the live API providing river data.

    Returns:
    pandas.DataFrame: A DataFrame of tide data filtered by unit (mASD), indexed by 
                      stationReference and dateTime, with relevant data included.
    """
    data = urllib.request.urlopen(url_river)
    data = json.load(data)

    df_item = pd.DataFrame(data["items"])

    id_data = df_item["@id"].apply(split_level_api_id)
    df_item["stationReference"] = id_data.apply(extract_station_reference)
    df_item["qualifier"] = id_data.apply(extract_qualifier)
    df_item["unitName"] = id_data.apply(extract_unit_name)


    df_item.drop(["@id", "measure"], axis=1, inplace=True)

    df_item["dateTime"] = df_item["dateTime"].apply(pd.to_datetime)

    df_item.set_index(["stationReference", "dateTime"], inplace=True)

    # df_item["parameter"] = "rainfail"

    df_item["value"] = pd.to_numeric(df_item["value"], errors="coerce")
    # df_item.dropna(['unitName'], inplace=True)
    df_item = df_item[df_item['unitName'] == 'mASD']

    return df_item.sort_index()

url_tide= "http://environment.data.gov.uk/flood-monitoring/data/readings?latest"

live_river = get_latest_river_readings(url_tide)#.shape#parameter.value_counts()
live_river.reset_index(inplace=True)
live_river
# Out:
#      stationReference                  dateTime  value  qualifier unitName
# 0              0130TH 2024-11-21 23:00:00+00:00  0.250      Stage     mASD
# 1              0130TH 2024-11-21 23:00:00+00:00  0.140  Downstage     mASD
# 2              0144TH 2024-11-21 23:00:00+00:00  1.177      Stage     mASD
# 3              0155TH 2024-11-21 23:00:00+00:00  0.888  Downstage     mASD
# 4              0155TH 2024-11-21 23:00:00+00:00  0.875      Stage     mASD
# ...               ...                       ...    ...        ...      ...
# 1315            L3211 2024-11-21 23:00:00+00:00  2.443  Downstage     mASD
# 1316            L3211 2024-11-21 23:00:00+00:00  1.533      Stage     mASD
# 1317   PCHURCH_TG_342 2024-11-21 23:00:00+00:00  0.438      Stage     mASD
# 1318            SE560 2024-11-21 23:00:00+00:00  0.682      Stage     mASD
# 1319            SE730 2024-11-21 23:00:00+00:00  0.213      Stage     mASD
#
# [1320 rows x 5 columns]

# %% [markdown]
# # 2. Call a function of flood_tool to process the data

# %% [markdown]
# ## 2.1 live_rainfall processing

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.ensemble import RandomForestRegressor
import os
import sys
sys.path.append('..') # Add parent directory to path to always find flood_tool
                      # This is not best practice, but it works for this example
import flood_tool as ft


# Use the groupby function to group stationReference, calculate mean, max, min
live_rainfall_group=live_rainfall.groupby('stationReference')['value'].agg(['mean', 'max', 'min'])
live_rainfall_group.reset_index(inplace=True)
live_rainfall_group['max_min']=live_rainfall_group['max']-live_rainfall_group['min']
live_rainfall_group
    

station_path = "../flood_tool/resources/stations.csv"
station_loc=ft.read_data(station_path)
# # Connecting station and live_rainfall data using the station_rainfall_loc function
live_rainfall_station=ft.station_rainfall_loc(live_rainfall_group,station_loc)
live_rainfall_station.dropna(subset=['latitude'], inplace=True)

# The value data in live_rainfall_station is processed using the classify_rainfall and classify_rainfall_encode functions to classify the data
live_rainfall_station['rainfall_class'] = live_rainfall_station['mean'].apply(ft.classify_rainfall)
live_rainfall_station['rainfall_class_encode'] = live_rainfall_station['rainfall_class'].apply(ft.classify_rainfall_encode)
live_rainfall_station['rainfall_class_max'] = live_rainfall_station['max'].apply(ft.classify_rainfall)
live_rainfall_station['rainfall_class_encode_max'] = live_rainfall_station['rainfall_class_max'].apply(ft.classify_rainfall_encode)
live_rainfall_station.dropna(inplace=True)
live_rainfall_station
# Out:
#      stationReference  mean  max  min  max_min       stationName   latitude  \
# 0              000008   0.0  0.0  0.0      0.0  Rainfall station  53.480556
# 1              000028   0.0  0.0  0.0      0.0  Rainfall station  53.500289
# 2            000075TP   0.0  0.0  0.0      0.0  Rainfall station  51.084022
# 3            000076TP   0.0  0.0  0.0      0.0  Rainfall station  51.701508
# 4            000180TP   0.0  0.0  0.0      0.0  Rainfall station  51.618838
# ..                ...   ...  ...  ...      ...               ...        ...
# 884             E9360   0.0  0.0  0.0      0.0  Rainfall station  50.929113
# 885             E9660   0.0  0.0  0.0      0.0  Rainfall station  50.929364
# 886             E9720   0.0  0.0  0.0      0.0  Rainfall station  50.860296
# 887            EdgeH1   0.0  0.0  0.0      0.0  Rainfall station  53.560463
# 891  VCHURCH-T_TG_341   0.0  0.0  0.0      0.0  Rainfall station  52.023749
#
#      longitude        easting       northing rainfall_class  \
# 0    -1.441674  437150.512108  398348.710960         Slight
# 1    -1.673575  421750.534631  400448.642470         Slight
# 2    -0.214597  525150.530744  133149.574480         Slight
# 3    -0.747539  486650.531968  201049.405434         Slight
# 4     0.173236  550550.534797  193349.379816         Slight
# ..         ...            ...            ...            ...
# 884  -0.384184  513650.529609  115649.665558         Slight
# 885  -0.469557  507650.524814  115549.681959         Slight
# 886  -0.483186  506850.555277  107849.746269         Slight
# 887  -2.873303  342250.520990  407448.681306         Slight
# 891  -2.921750  336850.530473  236549.288757         Slight
#
#      rainfall_class_encode rainfall_class_max  rainfall_class_encode_max
# 0                        0             Slight                          0
# 1                        0             Slight                          0
# 2                        0             Slight                          0
# 3                        0             Slight                          0
# 4                        0             Slight                          0
# ..                     ...                ...                        ...
# 884                      0             Slight                          0
# 885                      0             Slight                          0
# 886                      0             Slight                          0
# 887                      0             Slight                          0
# 891                      0             Slight                          0
#
# [833 rows x 14 columns]

# %% [markdown]
# ## 2.2 live_tide processing

# %% [markdown]
# ## 2.3 live_river processing

# %% [markdown]
# # 3. Call the draw function to plot the potential areas at risk.
